# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter33 ~ 41 수업은 잘 들으셨나요?
#
# Chapter33 ~ 41의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# [문제 1]
#
# 사용자로부터 두 개의 숫자를 입력받아 나눗셈을 수행하는 프로그램을 작성하세요.
#
# [예외처리]
# - 입력 값이 숫자가 아닐 때 발생할 수 있는 ValueError
# - 나누는 수가 0일 때 발생할 수 있는 ZeroDivisionError
# - 위 2가지 예외처리 후 사용자에게 이해하기 쉬운 메시지 작성 후 출력되도록 코드를 작성

# %%
try:
    x, y = map(int, input("숫자를 입력해주세요").split(" "))
    print(f'"x / y:", {x / y}' )
except ValueError:
    print("정수를 입력해주세요")
except ZeroDivisionError:
    print("나누는 수가 0이면 안됩니다")
# Out:
# "x / y:", 3.3333333333333335

# %% [markdown]
# ---

# %% [markdown]
# [문제 2]
#
# 파일을 읽어서 내용을 출력하는 프로그램을 작성하세요.
#
# - 파일이 존재하지 않을 때 발생하는 FileNotFoundError를 처리
# - 파일이 존재하지 않을 경우 "파일을 찾을 수 없습니다."라는 메시지를 출력

# %%
def find_file():
    try:
        with open(find_file, 'r'):
            print(find_file())
    
    except FileNotFoundError:
        print("파일을 찾을수 없습니다")

# %% [markdown]
# ---

# %% [markdown]
# [문제 3]
#
# 사용자로부터 여러 개의 숫자를 입력받아 리스트에 저장한 후, 사용자가 'done'이라고 입력할 때까지 계속 입력받으세요.
#
# - 입력 중 숫자가 아닌 값이 입력되면 ValueError를 처리
# - 숫자 외 값이 입력된 경우 어떤 값이 잘못 입력되었는지 사용자에게 알려주는 문구 출력<br>
#   (예: f"잘못된 값: {변수}. 숫자를 입력해주세요.")

# %%
user_input = []
while True:
    try:
        users_input = input("여러개의 숫자를 입력하시오, ' done 입력시 종료 ")
        if users_input == 'done':
            break
        user_input.append(int(users_input))
    except ValueError:
        print(f'잘못된 값:{users_input}, 숫자를 입력해주세요')

# %% [markdown]
# ---

# %% [markdown]
# [문제 4]
#
# 사용자 정의 예외 NegativeNumberError를 생성하고, 사용자로부터 숫자를 입력받아 음수일 경우 NegativeNumberError를 발생시키는 프로그램을 작성하세요.
#
# - 예외 처리 구문을 사용하여 음수 입력 시 "양수를 입력해주세요."라는 메시지를 출력

# %%
class NegativeNumberError(Exception):
    def __init__(self, m):
        self.name = NegativeNumberError
        self.m = m
        super(). __init__({m})
        self.m = m

try:
    num = int(input("숫자를 입력해주세요"))
    if num < 0:
        raise NegativeNumberError("양수를 입력해주세요")       
except NegativeNumberError as n:
        print(n)
# Out:
# {'양수를 입력해주세요'}

# %% [markdown]
# ---

# %% [markdown]
# [문제 5]
#
# datetime 모듈을 사용하여 현재 날짜와 시간을 출력하는 프로그램을 작성하세요.
#
# 또한, 사용자로부터 태어난 년도를 입력받아 현재 나이를 계산하여 출력하세요.

# %%
from datetime import datetime
now = datetime.now()
print(now)

y = int(input("태어난연도"))
age = now.year - y
print(f'"현재 나이:"{age}')
# Out:
# 2025-11-27 15:23:44.577686
# "현재 나이:"23

# %% [markdown]
# ---

# %% [markdown]
# [문제 6]
#
# requests 모듈을 사용하여, 웹 페이지의 HTML을 가져오는 간단한 웹 스크레이퍼를 작성하세요.
#
# 'https://kream.co.kr/'에서<br>
# 데이터를 가져와서 상태 코드와 HTML의 첫 100자를 출력하세요.<br>
# (실습 전 requests 모듈을 설치해야 함)

# %%
import requests

dater = requests.get("https://kream.co.kr/")
print(dater.status_code)
print(dater.text[:100])
# Out:
# 500
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta name="robots" content="noindex, nofollow" />
# <meta htt

# %% [markdown]
# ---

# %% [markdown]
# [문제 7]
#
# 함수 실행 시간을 측정하는 데코레이터 timer_decorator를 작성하세요.
#
# 임의의 함수가 실행되는 시간을 측정하여 "함수 실행 시간: x.xx초" 형태로 출력하세요.

# %%
import time

def time_decorater(func):
    def timer(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        print(f'"함수내보내는시간 : {end - start:.2}"')
        return result
    return timer

@time_decorater
def timewatch():
    for i in range(3000000):
        pass
timewatch()
# Out:
# "함수내보내는시간 : 0.043"

# %% [markdown]
# ---

# %% [markdown]
# [문제 8]
#
# 여러분이 자주 사용하는 수학적 연산<br>
# (예: 삼각형 넓이, 원의 넓이, 직육면체의 넓이)을 수행하는 함수들을 포함하는 mymath.py라는 이름의 모듈을 만드세요.
#
# 이 모듈을 사용하여 작성된 함수들을 실제로 임포트하고 사용하는 간단한 프로그램을 작성하세요.

# %%
#mymath.py
def number_input():
    value = input("반지름을 입력하시오")
    return float(vlaue)
def get_triangle(radius):
    return radius * radius / 2
def get_circle(radius):
    return pi * radius * radius
def get_square(radius):
    return radius * radius

# %%
import mymath as m
radius = math_input()
print(m.get_triangle(radius))
print(m.get_circle(radius))
print(m.get_square(radius))

# %% [markdown]
# ---

# %% [markdown]
# [문제 9]
#
# animals라는 패키지를 만들고, 이 패키지 내에 mammals, birds라는 두 개의 서브 모듈을 생성하세요.
#
# - 각 모듈에는 최소한 한 개 이상의 동물에 관한 클래스를 정의하세요<br>
#   (예: mammals에는 Dog, birds에는 Eagle)
# - 이 패키지와 모듈을 사용하여 동물들의 정보를 출력하는 프로그램을 작성
#
# 폴더 및 파일 구조
# ```
# animals/(폴더)
# ├── __init__.py
# ├── mammals.py
# └── birds.py
# ```

# %%
#mammals.py
class Dog(animals):
    def act(self):
        return "멍멍"

# %%
#birds.py
class Eagle(animals):
    def act(self):
        return "삐약삐약"

# %%
import animals.mammals as Dog
import animals.birds as Eagle
dog = Dog()
eagle = Eagle()

# %% [markdown]
# ---
